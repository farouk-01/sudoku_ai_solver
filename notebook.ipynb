# %%
# %load_ext autoreload 
# %autoreload 2

# %%
from sudoku_4x4_generator import all_solutions
from visual_tools import *
from sym_classifier import *

# %%
sols = list(all_solutions())

# %%
len(sols)
# Out:
# 288

# %%
groups = classify(sols)

# %%
print("Nb solutions:", len(sols))
print("Nb classes (patterns):", len(groups))
# Out:
# Nb solutions: 288
# Nb classes (patterns): 5

# %%
reps = [grids[0] for grids in groups.values()]
show_patterns(reps)

# %%
hidden_groups = classify_reps_by_hidden(reps)
assign, chosen = classify_all_into_containers(sols, reps, hidden_groups)
show_all_container_assignments(assign, reps,hidden_groups, max_show=50)
# Out:
# ---- CONTAINER 0 | total members: 1 ----
# ---- CONTAINER 1 | total members: 0 ----
# ---- CONTAINER 2 | total members: 0 ----
# ---- CONTAINER 3 | total members: 1 ----
# ---- CONTAINER 4 | total members: 6 ----

# %%
final_containers, final_assign = expand_containers_until_full_cover(
    sols, reps, hidden_groups
)

print("Total containers needed:", len(final_containers))
# Out:
# Total containers needed: 191

# %%
# fake_hidden = {i: [i] for i in range(len(final_containers))}
# show_all_container_assignments(final_assign, final_containers, fake_hidden)

# %%
motifs, covers_out, ranks = build_hasse_by_motifs(sols, motif_set)
draw_hasse(covers_out, ranks, title="Hasse diagram for all 288 sudokus")

# %%
motifs_c, covers_out_c, ranks_c = build_hasse_by_motifs(final_containers, motif_set)
draw_hasse(covers_out_c, ranks_c, title="Hasse diagram of containers only")

# %%
sizes = show_largest_groups(groups, top=5) 
key0 = sizes[0][1]                        
show_group(groups, key0, per_row=10, max_show=10)
# Out:
# #1: taille=96
# #2: taille=96
# #3: taille=48
# #4: taille=24
# #5: taille=24

# %%
colA = [2,3,1,4]
colB = [1,4,3,2]

res = find_solutions_with_adjacent_cols( sols, colB, colA, allow_reversed=False, order_matters=True, start_col=2)

show_patterns(res, per_row=10)

# %%
sizes = show_largest_groups(groups, top=5)   
key0 = sizes[0][1]                           
show_group(groups, key0, per_row=10)
# Out:
# #1: taille=96
# #2: taille=96
# #3: taille=48
# #4: taille=24
# #5: taille=24

# %%
show_patterns(sols)
